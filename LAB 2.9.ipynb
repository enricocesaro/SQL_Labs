# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#additional modules to speak to sql

#!pip install pymysql -- installed already - how to install a module from inside jupiter

import pymysql
from sqlalchemy import create_engine

import getpass
password = getpass.getpass()

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)
query = '''SELECT RANK() OVER(ORDER BY length DESC) AS ranking, title, length
FROM sakila.film
WHERE length is not null OR length <> 0
ORDER BY ranking;'''
data = pd.read_sql_query(query, engine)
data.head(60)
# Out:
#     ranking                   title  length
# 0         1           CHICAGO NORTH     185
# 1         1          CONTROL ANTHEM     185
# 2         1          DARN FORRESTER     185
# 3         1             GANGS PRIDE     185
# 4         1               HOME PITY     185
# 5         1           MUSCLE BRIGHT     185
# 6         1            POND SEATTLE     185
# 7         1      SOLDIERS EVOLUTION     185
# 8         1       SWEET BROTHERHOOD     185
# 9         1            WORST BANGER     185
# 10       11       CONSPIRACY SPIRIT     184
# 11       11        CRYSTAL BREAKING     184
# 12       11          KING EVOLUTION     184
# 13       11         MOONWALKER FOOL     184
# 14       11         SMOOCHY CONTROL     184
# 15       11          SONS INTERVIEW     184
# 16       11          SORORITY QUEEN     184
# 17       11          THEORY MERMAID     184
# 18       19           CATCH AMISTAD     183
# 19       19          FRONTIER CABIN     183
# ...
